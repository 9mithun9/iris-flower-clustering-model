# %% [markdown]
# <a href="https://colab.research.google.com/github/9mithun9/iris-flower-clustering-model/blob/main/iris_flower_tSNE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd

# %%
iris_df = sns.load_dataset('iris')

# %%
numerical_cols = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']

# %%
x = iris_df[numerical_cols]

# %%
from sklearn.manifold import TSNE

# %%
tsne = TSNE(n_components=2, random_state=0)

# %%
x_tsne = tsne.fit_transform(x)

# %%
tsne_df = pd.DataFrame(x_tsne, columns=['tsne1', 'tsne2'])

# %%
tsne_df
# Out:
#          tsne1     tsne2
# 0   -24.284670 -0.196069
# 1   -21.731905  0.653882
# 2   -21.776773 -0.433848
# 3   -21.413086 -0.141203
# 4   -24.284908 -0.606254
# ..         ...       ...
# 145  14.369648 -2.493189
# 146  11.872075 -0.541414
# 147  13.772250 -1.774297
# 148  14.138768 -3.394210
# 149  10.997549 -0.581367
#
# [150 rows x 2 columns]

# %%
sns.scatterplot(x=x_tsne[:,0], y=x_tsne[:,1], hue=iris_df['species'])
# Out:
# <Axes: >
